# %%
#seg

#https://docs.ultralytics.com/zh/datasets/segment/coco/#usage

from ultralytics import YOLO

# Load a model
model = YOLO("model/yolo11n-seg.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="config/coco.yaml", epochs=100, imgsz=640,project="Coco",name="train-1-seg")

# %%
#驗證
from ultralytics import YOLO

model = YOLO("Coco/train-1-seg/weights/best.pt")  # 換成你的實際路徑
model.val(data="config/coco.yaml")
# Out:
# Ultralytics 8.3.114  Python-3.11.11 torch-2.8.0.dev20250409+cu128 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLO11n-seg summary (fused): 113 layers, 2,868,664 parameters, 0 gradients, 10.4 GFLOPs
# val: Fast image access  (ping: 0.10.1 ms, read: 557.2345.4 MB/s, size: 119.2 KB)
# val: Scanning D:\大學\專題\影像辨識芒果\datasets\coco\labels\val2017.cache... 4952 images, 48 backgrounds, 0 corrupt: 100%|██████████| 5000/5000 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/313 [00:00<?, ?it/s]
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# ...

# %%
#訓練黑點
from ultralytics import YOLO

# Load a model
model = YOLO(r"Coco\train-1-seg\weights\best.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(  data="config/test_segment.yaml",
                        batch=10, #同時學習四張照片
                        device=0, #使用GPU 0 , 
                        epochs=100, imgsz=640,project="Mango_dot",name="mango_dot"
                    )
# Out:
# New https://pypi.org/project/ultralytics/8.3.167 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.114  Python-3.11.11 torch-2.8.0.dev20250409+cu128 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.114  Python-3.11.11 torch-2.8.0.dev20250409+cu128 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Setup complete  (20 CPUs, 31.7 GB RAM, 777.0/953.9 GB disk)
